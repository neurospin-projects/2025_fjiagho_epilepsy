# %%
import pandas as pd

# %%
a = pd.read_csv("/neurospin/dico/fred/Runs/01_betaVAE/Program/2023_jlaval_STSbabies/betaVAE/notebooks/fred/epilepsy_PBS/with_all_the_regions/reconstruction_error/Kolmogorov Smirnov distance with cross entropy loss")

# %%
a
# Out:
#     Unnamed: 0                       regions  UKB and hcp  UKB and controls  \
# 0            0   FCLp-subsc-FCLa-INSULA_left     0.647411          0.436943
# 1            1  FCLp-subsc-FCLa-INSULA_right     0.654335          0.611514
# 2            2              FCMpost-SpC_left     0.519496          0.275385
# 3            3             FCMpost-SpC_right     0.541608          0.213353
# 4            4                FColl-SRh_left     0.636770          0.159856
# 5            5               FColl-SRh_right     0.598736          0.131814
# 6            6            FIP-FIPPoCinf_left     0.748861          0.378150
# 7            7           FIP-FIPPoCinf_right     0.735406          0.544853
# 8            8            FPO-SCu-ScCal_left     0.561295          0.283265
# 9            9           FPO-SCu-ScCal_right     0.616849          0.099220
# 10          10      Lobule_parietal_sup_left     0.714743          0.160459
# ...

# %%
b= a[["regions","UKB and hcp"]]

# %%
b
# Out:
#                          regions  UKB and hcp
# 0    FCLp-subsc-FCLa-INSULA_left     0.647411
# 1   FCLp-subsc-FCLa-INSULA_right     0.654335
# 2               FCMpost-SpC_left     0.519496
# 3              FCMpost-SpC_right     0.541608
# 4                 FColl-SRh_left     0.636770
# 5                FColl-SRh_right     0.598736
# 6             FIP-FIPPoCinf_left     0.748861
# 7            FIP-FIPPoCinf_right     0.735406
# 8             FPO-SCu-ScCal_left     0.561295
# 9            FPO-SCu-ScCal_right     0.616849
# 10      Lobule_parietal_sup_left     0.714743
# 11     Lobule_parietal_sup_right     0.713971
# 12                OCCIPITAL_left     0.377226
# 13               OCCIPITAL_right     0.468421
# 14                  SC-SPeC_left     0.610086
# 15                 SC-SPeC_right     0.605319
# 16                  SC-SPoC_left     0.673021
# 17                 SC-SPoC_right     0.655006
# 18                  SC-sylv_left     0.606386
# ...

# %%
b.to_csv("Distance_UKB_hcp")

# %% [markdown]
# Chamfer_distance

# %%
a = pd.read_csv("/neurospin/dico/fred/Runs/01_betaVAE/Program/2023_jlaval_STSbabies/betaVAE/notebooks/fred/epilepsy_PBS/with_all_the_regions/reconstruction_error/Ks_chamfer_distance")

# %%
a
# Out:
#     Unnamed: 0                       regions  UKB and hcp  UKB and controls  \
# 0            0   FCLp-subsc-FCLa-INSULA_left     0.509001          0.195230
# 1            1  FCLp-subsc-FCLa-INSULA_right     0.568046          0.698373
# 2            2              FCMpost-SpC_left     0.467094          0.429063
# 3            3             FCMpost-SpC_right     0.511589          0.228479
# 4            4                FColl-SRh_left     0.623947          0.173758
# 5            5               FColl-SRh_right     0.525696          0.131484
# 6            6            FIP-FIPPoCinf_left     0.565706          0.300413
# 7            7           FIP-FIPPoCinf_right     0.612179          0.325236
# 8            8            FPO-SCu-ScCal_left     0.486351          0.168338
# 9            9           FPO-SCu-ScCal_right     0.605242          0.170968
# 10          10      Lobule_parietal_sup_left     0.570633          0.369715
# ...

# %%
b= a[["regions", "UKB and hcp"]]

# %%
b.to_csv("Distance_UKB_hcp_Chamfer")
