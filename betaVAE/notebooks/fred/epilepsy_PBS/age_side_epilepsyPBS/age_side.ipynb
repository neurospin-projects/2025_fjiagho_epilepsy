# %% [markdown]
# The goal of this file is to plot the reconstruction error as a function of the age for all the subject in epilpesy_PBS and to plot the histogram given the fact that the lession is at the right or at the left

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_plos_one_2015_anon.csv", sep=";")

# %%
df_control = {
    "Index": [
        "control01", "control02", "control03", "control04", "control05",
        "control06", "control07", "control08", "control09", "control10",
        "control11", "control12", "control14", "control15", "control16",
        "control17", "control18", "control19", "control20"
    ],
    "agealirm": [
         22, 32, 50, 18, 23,
         26, 26, 24, 21, 31,
         34, 34, 36, 28, 25,
         31, 24, 25, 31
    ],
    "sex": [
        "f", "m", "f", "f", "f",
        "m", "f", "m", "f", "f",
        "f", "f", "f", "m", "m",
        "f", "m", "f", "f"
    ]
}

df_control = pd.DataFrame(df_control)
df_control.to_csv("Controls.csv")

# %%
df
# Out:
#         subject   IRM     group    lesion  agealirm sex handedness lesion_side
# 0   sujet01_neg  1.5T  patients  negative        12   f          D           D
# 1   sujet08_neg  1.5T  patients  negative        11   m          D           D
# 2   sujet10_neg  1.5T  patients  negative        12   m          D           D
# 3   sujet12_neg  1.5T  patients  negative        17   f          D           D
# 4   sujet20_neg  1.5T  patients  negative         7   f          D           D
# 5   sujet22_neg  1.5T  patients  negative        42   f          D           D
# 6   sujet23_neg  1.5T  patients  negative         9   f          D           D
# 7   sujet02_pos  1.5T  patients  positive        19   m          D           D
# 8   sujet04_pos  1.5T  patients  positive        29   m          D           D
# 9   sujet05_pos  1.5T  patients  positive        32   f          G           D
# 10  sujet06_pos  1.5T  patients  positive        13   m          D           D
# 11  sujet07_pos  1.5T  patients  positive        36   m          G           D
# 12  sujet08_pos  1.5T  patients  positive        40   f          D           D
# 13  sujet10_pos  1.5T  patients  positive        11   f          D           D
# 14  sujet11_pos  1.5T  patients  positive        29   f          G           D
# 15  sujet13_pos  1.5T  patients  positive        43   f          G           D
# 16  sujet36_pos    3T  patients  positive        18   m          D           D
# 17  sujet40_pos    3T  patients  positive        16   m          D           D
# 18  sujet03_neg  1.5T  patients  negative        24   f          G           G
# 19  sujet07_neg  1.5T  patients  negative        16   m          D           G
# 20  sujet13_neg  1.5T  patients  negative         7   f          D           G
# 21  sujet15_neg  1.5T  patients  negative        16   f          D           G
# 22  sujet16_neg  1.5T  patients  negative        20   m          D           G
# 23  sujet26_neg    3T  patients  negative        29   f          D           G
# 24  sujet03_pos  1.5T  patients  positive        20   m          G           G
# 25  sujet09_pos  1.5T  patients  positive        46   m          D           G
# 26  sujet14_pos  1.5T  patients  positive        19   f          G           G
# 27  sujet15_pos  1.5T  patients  positive        22   m          G           G
# 28  sujet20_pos  1.5T  patients  positive        29   f          D           G
# 29  sujet29_pos  1.5T  patients  positive        20   m          D           G
# 30  sujet32_pos  1.5T  patients  positive        42   m          D           G
# 31  sujet33_pos  1.5T  patients  positive        20   f          D           G
# 32  sujet34_pos  1.5T  patients  positive        24   m          D           G
# 33  sujet35_pos    3T  patients  positive        45   f          G           G
# 34  sujet37_pos    3T  patients  positive        37   m          D           G
# 35  sujet38_pos    3T  patients  positive        67   f          D           G
# 36  sujet39_pos    3T  patients  positive        24   m          D           G
# 37  sujet41_pos    3T  patients  positive        23   f          D           D

# %%
error= pd.read_csv("/neurospin/tmp/fred/models/2025-11-10/SC-sylv_right_UKB_16-20-03_123/epilepsy_PBS/Reconstruction_error.csv")

# %%
error
# Out:
#      Unnamed: 0            0
# 0     control01  3217.521729
# 1     control02  3201.776367
# 2     control03  4088.432129
# 3     control04  2775.782715
# 4     control05  3493.113281
# 5     control06  3862.013672
# 6     control07  3310.393066
# 7     control08  3506.626709
# 8     control09  4038.550049
# 9     control10  2989.376465
# 10    control11  3165.589355
# 11    control12  3422.444580
# 12    control14  3681.561523
# 13    control15  3623.182373
# 14    control16  4382.430664
# 15    control17  3747.852295
# 16    control18  2981.914062
# 17    control19  2812.433838
# 18    control20  3299.005371
# 19  sujet01_neg  4203.624023
# 20  sujet02_pos  5134.915527
# 21  sujet03_neg  3633.142578
# 22  sujet03_pos  4975.172852
# 23  sujet04_pos  3499.770020
# 24  sujet05_pos  3591.159180
# 25  sujet06_pos  3993.062988
# 26  sujet07_neg  3983.527588
# 27  sujet07_pos  3732.664062
# 28  sujet08_neg  4960.020508
# 29  sujet08_pos  3093.048340
# 30  sujet09_pos  4331.233887
# 31  sujet10_neg  4753.197266
# 32  sujet10_pos  5090.575684
# 33  sujet11_pos  2830.882324
# 34  sujet12_neg  4691.456055
# 35  sujet13_neg  5479.308594
# 36  sujet13_pos  4401.250000
# 37  sujet14_pos  4144.845215
# 38  sujet15_neg  3855.137939
# 39  sujet15_pos  4580.122070
# 40  sujet16_neg  4289.882324
# 41  sujet20_neg  5346.845703
# 42  sujet20_pos  3756.492920
# 43  sujet22_neg  3948.347900
# 44  sujet23_neg  4748.267578
# 45  sujet26_neg  4532.148438
# 46  sujet29_pos  4095.055420
# 47  sujet32_pos  3658.605469
# 48  sujet33_pos  3953.663330
# 49  sujet34_pos  4094.609863
# 50  sujet35_pos  4588.481445
# 51  sujet36_pos  4801.316895
# 52  sujet37_pos  4301.066406
# 53  sujet38_pos  3236.264648
# 54  sujet39_pos  3258.878906
# 55  sujet40_pos  3225.300049
# 56  sujet41_pos  4355.004883

# %%
Participants_epilepsy=pd.read_csv("/neurospin/dico/data/human/epilepsy_PBS/participants.tsv", sep="\t")

# %%
epilepsy_controls= Participants_epilepsy[Participants_epilepsy["Diagnosis"]=="controls"]
epilepsy_irm_neg= Participants_epilepsy[Participants_epilepsy["Diagnosis"]=="irm_negatives_centrales"]
epilepsy_irm_pos= Participants_epilepsy[Participants_epilepsy["Diagnosis"]=="irm_positives_centrales"]

# %%
error  = error.rename(columns={error.columns[0]: "Index"})

# %%
df = df.rename(columns={df.columns[0]: "Index"})

# %%
error_controls = error.merge(epilepsy_controls[["Index"]], on="Index", how="inner")
error_irm_neg = error.merge(epilepsy_irm_neg[["Index"]], on="Index", how="inner")
error_irm_pos = error.merge(epilepsy_irm_pos[["Index"]], on="Index", how="inner")

# %%
error_controls
# Out:
#         Index            0
# 0   control01  3217.521729
# 1   control02  3201.776367
# 2   control03  4088.432129
# 3   control04  2775.782715
# 4   control05  3493.113281
# 5   control06  3862.013672
# 6   control07  3310.393066
# 7   control08  3506.626709
# 8   control09  4038.550049
# 9   control10  2989.376465
# 10  control11  3165.589355
# 11  control12  3422.444580
# 12  control14  3681.561523
# 13  control15  3623.182373
# 14  control16  4382.430664
# 15  control17  3747.852295
# 16  control18  2981.914062
# 17  control19  2812.433838
# 18  control20  3299.005371

# %%
df_contr= df_control.merge(error_controls, on ="Index", how="inner")
df_neg= df.merge(error_irm_neg, on ="Index", how="inner")
df_pos= df.merge(error_irm_pos, on ="Index", how="inner")

# %%
df_neg
# Out:
#           Index   IRM     group    lesion  agealirm sex handedness  \
# 0   sujet01_neg  1.5T  patients  negative        12   f          D
# 1   sujet08_neg  1.5T  patients  negative        11   m          D
# 2   sujet10_neg  1.5T  patients  negative        12   m          D
# 3   sujet12_neg  1.5T  patients  negative        17   f          D
# 4   sujet20_neg  1.5T  patients  negative         7   f          D
# 5   sujet22_neg  1.5T  patients  negative        42   f          D
# 6   sujet23_neg  1.5T  patients  negative         9   f          D
# 7   sujet03_neg  1.5T  patients  negative        24   f          G
# 8   sujet07_neg  1.5T  patients  negative        16   m          D
# 9   sujet13_neg  1.5T  patients  negative         7   f          D
# 10  sujet15_neg  1.5T  patients  negative        16   f          D
# 11  sujet16_neg  1.5T  patients  negative        20   m          D
# 12  sujet26_neg    3T  patients  negative        29   f          D
#
#    lesion_side            0
# 0            D  4203.624023
# 1            D  4960.020508
# 2            D  4753.197266
# 3            D  4691.456055
# 4            D  5346.845703
# 5            D  3948.347900
# 6            D  4748.267578
# 7            G  3633.142578
# 8            G  3983.527588
# 9            G  5479.308594
# 10           G  3855.137939
# 11           G  4289.882324
# 12           G  4532.148438

# %%
df_pos
# Out:
#           Index   IRM     group    lesion  agealirm sex handedness  \
# 0   sujet02_pos  1.5T  patients  positive        19   m          D
# 1   sujet04_pos  1.5T  patients  positive        29   m          D
# 2   sujet05_pos  1.5T  patients  positive        32   f          G
# 3   sujet06_pos  1.5T  patients  positive        13   m          D
# 4   sujet07_pos  1.5T  patients  positive        36   m          G
# 5   sujet08_pos  1.5T  patients  positive        40   f          D
# 6   sujet10_pos  1.5T  patients  positive        11   f          D
# 7   sujet11_pos  1.5T  patients  positive        29   f          G
# 8   sujet13_pos  1.5T  patients  positive        43   f          G
# 9   sujet36_pos    3T  patients  positive        18   m          D
# 10  sujet40_pos    3T  patients  positive        16   m          D
# 11  sujet03_pos  1.5T  patients  positive        20   m          G
# 12  sujet09_pos  1.5T  patients  positive        46   m          D
# 13  sujet14_pos  1.5T  patients  positive        19   f          G
# 14  sujet15_pos  1.5T  patients  positive        22   m          G
# 15  sujet20_pos  1.5T  patients  positive        29   f          D
# 16  sujet29_pos  1.5T  patients  positive        20   m          D
# 17  sujet32_pos  1.5T  patients  positive        42   m          D
# 18  sujet33_pos  1.5T  patients  positive        20   f          D
# 19  sujet34_pos  1.5T  patients  positive        24   m          D
# 20  sujet35_pos    3T  patients  positive        45   f          G
# 21  sujet37_pos    3T  patients  positive        37   m          D
# 22  sujet38_pos    3T  patients  positive        67   f          D
# 23  sujet39_pos    3T  patients  positive        24   m          D
# 24  sujet41_pos    3T  patients  positive        23   f          D
#
#    lesion_side            0
# 0            D  5134.915527
# 1            D  3499.770020
# 2            D  3591.159180
# 3            D  3993.062988
# 4            D  3732.664062
# 5            D  3093.048340
# 6            D  5090.575684
# 7            D  2830.882324
# 8            D  4401.250000
# 9            D  4801.316895
# 10           D  3225.300049
# 11           G  4975.172852
# 12           G  4331.233887
# 13           G  4144.845215
# 14           G  4580.122070
# 15           G  3756.492920
# 16           G  4095.055420
# 17           G  3658.605469
# 18           G  3953.663330
# 19           G  4094.609863
# 20           G  4588.481445
# 21           G  4301.066406
# 22           G  3236.264648
# 23           G  3258.878906
# 24           D  4355.004883

# %%
df_contr = df_contr.rename(columns={'0': 'error'})
df_neg = df_neg.rename(columns={'0': 'error'})
df_pos = df_pos.rename(columns={'0': 'error'})
df_neg
# Out:
#           Index   IRM     group    lesion  agealirm sex handedness  \
# 0   sujet01_neg  1.5T  patients  negative        12   f          D
# 1   sujet08_neg  1.5T  patients  negative        11   m          D
# 2   sujet10_neg  1.5T  patients  negative        12   m          D
# 3   sujet12_neg  1.5T  patients  negative        17   f          D
# 4   sujet20_neg  1.5T  patients  negative         7   f          D
# 5   sujet22_neg  1.5T  patients  negative        42   f          D
# 6   sujet23_neg  1.5T  patients  negative         9   f          D
# 7   sujet03_neg  1.5T  patients  negative        24   f          G
# 8   sujet07_neg  1.5T  patients  negative        16   m          D
# 9   sujet13_neg  1.5T  patients  negative         7   f          D
# 10  sujet15_neg  1.5T  patients  negative        16   f          D
# 11  sujet16_neg  1.5T  patients  negative        20   m          D
# 12  sujet26_neg    3T  patients  negative        29   f          D
#
#    lesion_side        error
# 0            D  4203.624023
# 1            D  4960.020508
# 2            D  4753.197266
# 3            D  4691.456055
# 4            D  5346.845703
# 5            D  3948.347900
# 6            D  4748.267578
# 7            G  3633.142578
# 8            G  3983.527588
# 9            G  5479.308594
# 10           G  3855.137939
# 11           G  4289.882324
# 12           G  4532.148438

# %%
plt.scatter(df_contr['agealirm'], df_contr['error'], label="controls")
plt.scatter(df_neg['agealirm'], df_neg['error'], label="irm_neg")
plt.scatter(df_pos['agealirm'], df_pos['error'], label="irm_pos")

plt.xlabel("age")
plt.ylabel("Reconstruction error")
plt.legend()
plt.show()

# %%
df_neg_D = df_neg[df_neg['lesion_side']=='D']
df_neg_G = df_neg[df_neg['lesion_side']=='G']

df_pos_D = df_pos[df_pos['lesion_side']=='D']
df_pos_G = df_pos[df_pos['lesion_side']=='G']

# %%
print(df_neg_D['error'].mean())
print(df_neg_G['error'].mean())
print(df_pos_D['error'].mean())
print(df_pos_G['error'].mean())
# Out:
# 4664.537004743303
# 4295.524576822917
# 3979.0791625976562
# 4074.960956280048

# %%
plt.hist(error_controls.iloc[:,1], bins="auto", alpha=0.5, label="controls", density=True)
plt.hist(df_neg_D['error'], bins="auto", alpha=0.5, label="irm_neg avec lesion à droite", density=True)
plt.hist(df_neg_G['error'], bins="auto", alpha=0.5, label="irm_neg avec lesion à gauche", density=True)
plt.hist(df_pos_D['error'], bins="auto", alpha=0.5, label="irm_pos avec lesion à droite", density=True)
plt.hist(df_pos_G['error'], bins="auto", alpha=0.5, label="irm_pos avec lesion à gauche", density=True)

plt.xlabel("Reconstruction_error")

plt.title("Histogramme des erreurs de reconstruction")
plt.legend()
plt.show()

# %%
df_neg_m = df_neg[df_neg['sex']=='m']
df_neg_f = df_neg[df_neg['sex']=='f']

df_pos_m = df_pos[df_pos['sex']=='m']
df_pos_f = df_pos[df_pos['sex']=='f']

# %%
print(df_neg_m['error'].mean())
print(df_neg_f['error'].mean())
print(df_pos_m['error'].mean())
print(df_pos_f['error'].mean())
# Out:
# 4496.656921386719
# 4493.14208984375
# 4120.126743861607
# 3912.87890625

# %%
plt.hist(error_controls.iloc[:,1], bins="auto", alpha=0.5, label="controls", density=True)
plt.hist(df_neg_m['error'], bins="auto", alpha=0.5, label="irm_neg masculin", density=True)
plt.hist(df_neg_f['error'], bins="auto", alpha=0.5, label="irm_neg feminin", density=True)
plt.hist(df_pos_m['error'], bins="auto", alpha=0.5, label="irm_pos masculin", density=True)
plt.hist(df_pos_f['error'], bins="auto", alpha=0.5, label="irm_pos feminin", density=True)

plt.xlabel("Reconstruction_error")

plt.title("Histogramme des erreurs de reconstruction")
plt.legend()
plt.show()
