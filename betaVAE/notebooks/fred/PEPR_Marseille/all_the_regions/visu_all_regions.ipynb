# %%
import anatomist.api as anatomist
from soma.qt_gui.qtThread import QtThreadCall
from soma.qt_gui.qt_backend import Qt

# %%
from soma import aims
import json
import sys
import pandas as pd
import scipy
import scipy.stats
import numpy as np
import glob

# %%
a = anatomist.Anatomist()
# Out:
# global modules: /casa/host/build/share/anatomist-5.2/python_plugins
# home   modules: /casa/home/.anatomist/python_plugins
# loading module gltf_io
# loading module palettecontrols
# loading module measure
# loading module paletteViewer
# loading module meshsplit
# loading module profilewindow
# loading module ana_image_math
# loading module anacontrolmenu
# loading module foldsplit
# loading module modelGraphs
# loading module bsa_proba
# loading module histogram
# loading module gradientpalette
# loading module infowindow
# loading module simple_controls
# loading module volumepalettes
# loading module statsplotwindow
# loading module save_resampled
# loading module valuesplotwindow
# loading module selection
# all python modules loaded
# Anatomist started.

# %%
Rspam_model = "/casa/host/build/share/brainvisa-share-5.2/models/models_2008/descriptive_models/segments/global_registered_spam_right/meshes/Rspam_model_meshes_1.arg"

Lspam_model = "/casa/host/build/share/brainvisa-share-5.2/models/models_2008/descriptive_models/segments/global_registered_spam_left/meshes/Lspam_model_meshes_1.arg"

json_regions = "/neurospin/dico/data/deep_folding/current/sulci_regions_champollion_V1.json"

path_summary = "/neurospin/dico/fred/Runs/01_betaVAE/Program/2023_jlaval_STSbabies/betaVAE/notebooks/fred/PEPR_Marseille/Selected subjects/For each subject/Evaluation_metrics_with_v4/Quantile for each subject/with_mean"
path_file = "frequency_for_each_region"

# %%
with open(json_regions) as f:
    regions = json.load(f)

# %%
regions['brain']
# Out:
# {'S.C.-sylv._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left']},
#  'S.C.-S.Pe.C._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left'],
#   'S.Pe.C.inf._left': ['S.Pe.C.inf._left'],
#   'S.Pe.C.inter._left': ['S.Pe.C.inter._left'],
#   'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'],
#   'S.Pe.C.sup._left': ['S.Pe.C.sup._left'],
#   'S.Pe.C.median._left': ['S.Pe.C.median._left']},
#  'S.C.-S.Po.C._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left'],
#   'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'],
#   'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']},
#  'S.Pe.C._left': {'S.Pe.C.inf._left': ['S.Pe.C.inf._left'],
#   'S.Pe.C.inter._left': ['S.Pe.C.inter._left'],
#   'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'],
#   'S.Pe.C.sup._left': ['S.Pe.C.sup._left'],
#   'S.Pe.C.median._left': ['S.Pe.C.median._left']},
#  'S.Po.C._left': {'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'],
#   'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']},
#  'S.F.int.-F.C.M.ant._left': {'F.C.M.ant._left': ['F.C.M.ant._left'],
#   'S.F.int._left': ['S.F.int._left']},
#  'S.F.inf.-BROCA-S.Pe.C.inf._left': {'S.F.inf._left': ['S.F.inf._left'],
#   'S.F.inf.ant._left': ['S.F.inf.ant._left'],
#   'F.C.L.r.ant._left': ['F.C.L.r.ant._left'],
#   'F.C.L.r.asc._left': ['F.C.L.r.asc._left'],
#   'F.C.L.r.diag._left': ['F.C.L.r.diag._left'],
#   'S.Pe.C.inf._left': ['S.Pe.C.inf._left']},
#  'S.T.s._left': {'S.T.s._left': ['S.T.s._left']},
#  'Sc.Cal.-S.Li._left': {'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'],
#   'S.O.p._left': ['S.O.p._left'],
#   'S.Li.ant._left': ['S.Li.ant._left'],
#   'S.Li.post._left': ['S.Li.post._left']},
#  'F.C.M.post.-S.p.C._left': {'F.C.M.post._left': ['F.C.M.post._left'],
#   'S.C.LPC._left': ['S.C.LPC._left'],
#   'S.p.C._left': ['S.p.C._left']},
#  'S.T.i.-S.O.T.lat._left': {'S.T.i.ant._left': ['S.T.i.ant._left'],
#   'S.T.i.post._left': ['S.T.i.post._left'],
#   'S.O.T.lat.ant._left': ['S.O.T.lat.ant._left'],
#   'S.O.T.lat.int._left': ['S.O.T.lat.int._left'],
#   'S.O.T.lat.med._left': ['S.O.T.lat.med._left'],
#   'S.O.T.lat.post._left': ['S.O.T.lat.post._left']},
#  'OCCIPITAL_left': {'OCCIPITAL_left': ['OCCIPITAL_left']},
#  'F.I.P.-F.I.P.Po.C.inf._left': {'F.I.P._left': ['F.I.P._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left']},
#  'S.F.inter.-S.F.sup._left': {'S.F.inter._left': ['S.F.inter._left'],
#   'S.F.sup._left': ['S.F.sup._left']},
#  'S.F.median-S.F.pol.tr.-S.F.sup._left': {'S.F.median._left': ['S.F.median._left'],
#   'S.F.polaire.tr._left': ['S.F.polaire.tr._left'],
#   'S.F.sup._left': ['S.F.sup._left']},
#  'S.Or._left': {'S.Or._left': ['S.Or._left']},
#  'S.Or.-S.Olf._left': {'S.Or._left': ['S.Or._left'],
#   'S.Olf._left': ['S.Olf._left']},
#  'F.P.O.-S.Cu.-Sc.Cal._left': {'F.P.O._left': ['F.P.O._left'],
#   'S.Pa.t._left': ['S.Pa.t._left'],
#   'S.Cu._left': ['S.Cu._left'],
#   'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'],
#   'S.O.p._left': ['S.O.p._left']},
#  'S.s.P.-S.Pa.int._left': {'S.s.P._left': ['S.s.P._left'],
#   'S.Pa.int._left': ['S.Pa.int._left']},
#  'S.T.s.br._left': {'F.I.P.r.int.1_left': ['F.I.P.r.int.1_left'],
#   'F.I.P.r.int.2_left': ['F.I.P.r.int.2_left'],
#   'S.T.s.ter.asc.ant._left': ['S.T.s.ter.asc.ant._left'],
#   'S.T.s.ter.asc.post._left': ['S.T.s.ter.asc.post._left'],
#   'S.GSM._left': ['S.GSM._left']},
#  'Lobule_parietal_sup._left': {'F.I.P._left': ['F.I.P._left'],
#   'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'S.Pa.sup._left': ['S.Pa.sup._left']},
#  'S.F.marginal-S.F.inf.ant._left': {'S.F.marginal._left': ['S.F.marginal._left'],
#   'S.F.orbitaire._left': ['S.F.orbitaire._left'],
#   'S.F.inf.ant._left': ['S.F.inf.ant._left']},
#  'F.Coll.-S.Rh._left': {'F.Coll._left': ['F.Coll._left'],
#   'S.Rh._left': ['S.Rh._left']},
#  'S.T.i.-S.T.s.-S.T.pol._left': {'S.T.i.ant._left': ['S.T.i.ant._left'],
#   'S.T.i.post._left': ['S.T.i.post._left'],
#   'S.T.s._left': ['S.T.s._left'],
#   'S.T.pol._left': ['S.T.pol._left']},
#  'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left': {'F.C.L.p._left': ['F.C.L.p._left'],
#   'F.C.L.r.sc.ant._left': ['F.C.L.r.sc.ant._left'],
#   'F.C.L.r.sc.post._left': ['F.C.L.r.sc.post._left'],
#   'INSULA_left': ['INSULA_left'],
#   'F.C.L.a._left': ['F.C.L.a._left']},
#  'S.F.int.-S.R._left': {'S.F.int._left': ['S.F.int._left'],
#   'S.R.inf._left': ['S.R.inf._left'],
#   'S.R.sup._left': ['S.R.sup._left']},
#  'S.Call._left': {'S.Call._left': ['S.Call._left']},
#  'S.Call.-S.s.P.-S.intraCing._left': {'S.Call._left': ['S.Call._left'],
#   'S.s.P._left': ['S.s.P._left'],
#   'S.intraCing._left': ['S.intraCing._left']},
#  'S.C.-sylv._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right']},
#  'S.C.-S.Pe.C._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right'],
#   'S.Pe.C.inf._right': ['S.Pe.C.inf._right'],
#   'S.Pe.C.inter._right': ['S.Pe.C.inter._right'],
#   'S.Pe.C.marginal._right': ['S.Pe.C.marginal._right'],
#   'S.Pe.C.sup._right': ['S.Pe.C.sup._right'],
#   'S.Pe.C.median._right': ['S.Pe.C.median._right']},
#  'S.C.-S.Po.C._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right'],
#   'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right'],
#   'F.C.L.r.retroC.tr._right': ['F.C.L.r.retroC.tr._right']},
#  'S.Pe.C._right': {'S.Pe.C.inf._right': ['S.Pe.C.inf._right'],
#   'S.Pe.C.inter._right': ['S.Pe.C.inter._right'],
#   'S.Pe.C.marginal._right': ['S.Pe.C.marginal._right'],
#   'S.Pe.C.sup._right': ['S.Pe.C.sup._right'],
#   'S.Pe.C.median._right': ['S.Pe.C.median._right']},
#  'S.Po.C._right': {'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right'],
#   'F.C.L.r.retroC.tr._right': ['F.C.L.r.retroC.tr._right']},
#  'S.F.int.-F.C.M.ant._right': {'F.C.M.ant._right': ['F.C.M.ant._right'],
#   'S.F.int._right': ['S.F.int._right']},
#  'S.F.inf.-BROCA-S.Pe.C.inf._right': {'S.F.inf._right': ['S.F.inf._right'],
#   'S.F.inf.ant._right': ['S.F.inf.ant._right'],
#   'F.C.L.r.ant._right': ['F.C.L.r.ant._right'],
#   'F.C.L.r.asc._right': ['F.C.L.r.asc._right'],
#   'F.C.L.r.diag._right': ['F.C.L.r.diag._right'],
#   'S.Pe.C.inf._right': ['S.Pe.C.inf._right']},
#  'S.T.s._right': {'S.T.s._right': ['S.T.s._right']},
#  'Sc.Cal.-S.Li._right': {'F.Cal.ant.-Sc.Cal._right': ['F.Cal.ant.-Sc.Cal._right'],
#   'S.O.p._right': ['S.O.p._right'],
#   'S.Li.ant._right': ['S.Li.ant._right'],
#   'S.Li.post._right': ['S.Li.post._right']},
#  'F.C.M.post.-S.p.C._right': {'F.C.M.post._right': ['F.C.M.post._right'],
#   'S.C.LPC._right': ['S.C.LPC._right'],
#   'S.p.C._right': ['S.p.C._right']},
#  'S.T.i.-S.O.T.lat._right': {'S.T.i.ant._right': ['S.T.i.ant._right'],
#   'S.T.i.post._right': ['S.T.i.post._right'],
#   'S.O.T.lat.ant._right': ['S.O.T.lat.ant._right'],
#   'S.O.T.lat.int._right': ['S.O.T.lat.int._right'],
#   'S.O.T.lat.med._right': ['S.O.T.lat.med._right'],
#   'S.O.T.lat.post._right': ['S.O.T.lat.post._right']},
#  'OCCIPITAL_right': {'OCCIPITAL_right': ['OCCIPITAL_right']},
#  'F.I.P.-F.I.P.Po.C.inf._right': {'F.I.P._right': ['F.I.P._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right']},
#  'S.F.inter.-S.F.sup._right': {'S.F.inter._right': ['S.F.inter._right'],
#   'S.F.sup._right': ['S.F.sup._right']},
#  'S.F.median-S.F.pol.tr.-S.F.sup._right': {'S.F.median._right': ['S.F.median._right'],
#   'S.F.polaire.tr._right': ['S.F.polaire.tr._right'],
#   'S.F.sup._right': ['S.F.sup._right']},
#  'S.Or._right': {'S.Or._right': ['S.Or._right']},
#  'S.Or.-S.Olf._right': {'S.Or._right': ['S.Or._right'],
#   'S.Olf._right': ['S.Olf._right']},
#  'F.P.O.-S.Cu.-Sc.Cal._right': {'F.P.O._right': ['F.P.O._right'],
#   'S.Pa.t._right': ['S.Pa.t._right'],
#   'S.Cu._right': ['S.Cu._right'],
#   'F.Cal.ant.-Sc.Cal._right': ['F.Cal.ant.-Sc.Cal._right'],
#   'S.O.p._right': ['S.O.p._right']},
#  'S.s.P.-S.Pa.int._right': {'S.s.P._right': ['S.s.P._right'],
#   'S.Pa.int._right': ['S.Pa.int._right']},
#  'S.T.s.br._right': {'F.I.P.r.int.1_right': ['F.I.P.r.int.1_right'],
#   'F.I.P.r.int.2_right': ['F.I.P.r.int.2_right'],
#   'S.T.s.ter.asc.ant._right': ['S.T.s.ter.asc.ant._right'],
#   'S.T.s.ter.asc.post._right': ['S.T.s.ter.asc.post._right'],
#   'S.GSM._right': ['S.GSM._right']},
#  'Lobule_parietal_sup._right': {'F.I.P._right': ['F.I.P._right'],
#   'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'S.Pa.sup._right': ['S.Pa.sup._right']},
#  'S.F.marginal-S.F.inf.ant._right': {'S.F.marginal._right': ['S.F.marginal._right'],
#   'S.F.orbitaire._right': ['S.F.orbitaire._right'],
#   'S.F.inf.ant._right': ['S.F.inf.ant._right']},
#  'F.Coll.-S.Rh._right': {'F.Coll._right': ['F.Coll._right'],
#   'S.Rh._right': ['S.Rh._right']},
#  'S.T.i.-S.T.s.-S.T.pol._right': {'S.T.i.ant._right': ['S.T.i.ant._right'],
#   'S.T.i.post._right': ['S.T.i.post._right'],
#   'S.T.s._right': ['S.T.s._right'],
#   'S.T.pol._right': ['S.T.pol._right']},
#  'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right': {'F.C.L.p._right': ['F.C.L.p._right'],
#   'F.C.L.r.sc.ant._right': ['F.C.L.r.sc.ant._right'],
#   'F.C.L.r.sc.post._right': ['F.C.L.r.sc.post._right'],
#   'INSULA_right': ['INSULA_right'],
#   'F.C.L.a._right': ['F.C.L.a._right']},
#  'S.F.int.-S.R._right': {'S.F.int._right': ['S.F.int._right'],
#   'S.R.inf._right': ['S.R.inf._right'],
#   'S.R.sup._right': ['S.R.sup._right']},
#  'S.Call._right': {'S.Call._right': ['S.Call._right']},
#  'S.Call.-S.s.P.-S.intraCing._right': {'S.Call._right': ['S.Call._right'],
#   'S.s.P._right': ['S.s.P._right'],
#   'S.intraCing._right': ['S.intraCing._right']}}

# %%
len(regions['brain'])
# Out:
# 56

# %%
file_to_display = f"{path_summary}/{path_file}"

# %%
next(iter(regions['brain']))
# Out:
# 'S.C.-sylv._left'

# %%
df = pd.read_csv(file_to_display)[["region", "p"]]
#df["p"] = -np.log10(df["p"])
df.head()
# Out:
#                         region   p
# 0           STi-STs-STpol_left  29
# 1                     STs_left  22
# 2              STi-SOTlat_left  20
# 3  FCLp-subsc-FCLa-INSULA_left  19
# 4              FColl-SRh_right  17

# %%
#Pour mettre les valeurs entre 0 et 1
#df["p"] = (df["p"] - df["p"].min()) / (df["p"].max() - df["p"].min())
#df["p"] = (df["p"] - (-17.2)) / (6 - (-17.2))

# %%
df
# Out:
#                           region   p
# 0             STi-STs-STpol_left  29
# 1                       STs_left  22
# 2                STi-SOTlat_left  20
# 3    FCLp-subsc-FCLa-INSULA_left  19
# 4                FColl-SRh_right  17
# 5                     STsbr_left  16
# 6            STi-STs-STpol_right  15
# 7                 FColl-SRh_left  13
# 8                   SC-SPoC_left  12
# 9             FIP-FIPPoCinf_left  12
# 10              STi-SOTlat_right  12
# 11  SFmedian-SFpoltr-SFsup_right  11
# 12                     STs_right  11
# 13  FCLp-subsc-FCLa-INSULA_right  11
# 14      SFinf-BROCA-SPeCinf_left  10
# 15           SFinter-SFsup_right  10
# 16      Lobule_parietal_sup_left   9
# 17                     SPoC_left   9
# 18                 SFint-SR_left   8
# 19     SFinf-BROCA-SPeCinf_right   8
# 20                 SC-SPeC_right   7
# 21                   STsbr_right   7
# 22            SFinter-SFsup_left   7
# 23                  SC-SPeC_left   7
# 24             SFint-FCMant_left   6
# 25           FIP-FIPPoCinf_right   6
# 26            FPO-SCu-ScCal_left   6
# 27                 SC-SPoC_right   6
# 28                  SC-sylv_left   6
# 29   SFmedian-SFpoltr-SFsup_left   6
# 30     Lobule_parietal_sup_right   6
# 31                ScCal-SLi_left   5
# 32             FCMpost-SpC_right   5
# 33           FPO-SCu-ScCal_right   5
# 34                    SPeC_right   5
# 35            SFint-FCMant_right   5
# 36                OCCIPITAL_left   5
# 37     SCall-SsP-SintraCing_left   5
# 38                 SC-sylv_right   4
# 39              FCMpost-SpC_left   4
# 40              SsP-SPaint_right   4
# 41               SsP-SPaint_left   4
# 42                SFint-SR_right   4
# 43                    SPoC_right   4
# 44                     SPeC_left   4
# 45                    SCall_left   3
# 46    SCall-SsP-SintraCing_right   3
# 47               OCCIPITAL_right   3
# 48               ScCal-SLi_right   3
# 49      SFmarginal-SFinfant_left   3
# 50                SOr-SOlf_right   3
# 51                     SOr_right   3
# 52                   SCall_right   1
# 53                      SOr_left   1
# 54     SFmarginal-SFinfant_right   1
# 55                 SOr-SOlf_left   1

# %%
res = df.groupby(['region']).mean()
res["side"] = res.index.str.split('_').str[-1]
res = res.reset_index()

# %%
res = res[~res.region.str.contains("fronto-parietal")]
res = res[~res.region.str.contains("STs-SGSM")]
res = res[~res.region.str.contains("FCLp-SGSM")]
res = res[~res.region.str.contains("CINGULATE")]

# %%
"CINGULATE_left".replace("CINGULATE", "CINGULATE.")
# Out:
# 'CINGULATE._left'

# %%
def get_sulci(region):
    region = region.replace("CINGULATE", "CINGULATE.")
    region = region.replace("ORBITAL", "S.Or.")
    list_sulci = list(regions['brain'][f"{region}"].keys())
    list_sulci = [x.replace("paracingular.", "S.F.int.") for x in list_sulci]
    return list_sulci

# %%
get_sulci("S.C.-sylv._left")
# Out:
# ['S.C._left', 'S.C.sylvian._left']

# %%
dic = {
    "FCLp-subsc-FCLa-INSULA": "F.C.L.p.-subsc.-F.C.L.a.-INSULA.",
    "FCMpost-SpC": "F.C.M.post.-S.p.C.",
    "FColl-SRh": "F.Coll.-S.Rh.",
    "FIP": "F.I.P.",
    "FPO-SCu-ScCal": "F.P.O.-S.Cu.-Sc.Cal.",
    "Lobule_parietal_sup": "Lobule_parietal_sup.",
    "ORBITAL": "S.Or.",
    "SC-SPeC": "S.C.-S.Pe.C.",
    "SC-SPoC": "S.C.-S.Po.C.",
    "SC-sylv": "S.C.-sylv.",
    "SFinf-BROCA-SPeCinf": "S.F.inf.-BROCA-S.Pe.C.inf.",
    "SFint-FCMant": "S.F.int.-F.C.M.ant.",
    "SFint-SR": "S.F.int.-S.R.",
    "SFinter-SFsup": "S.F.inter.-S.F.sup.",
    "SFmarginal-SFinfant":"S.F.marginal-S.F.inf.ant.",
    "SFmedian-SFpoltr-SFsup": "S.F.median-S.F.pol.tr.-S.F.sup.",
    "SOr-SOlf": "S.Or.-S.Olf.",
    "SPeC": "S.Pe.C.",
    "SPoC": "S.Po.C.",
    "STi-SOTlat": "S.T.i.-S.O.T.lat.",
    "STi-STs-STpol": "S.T.i.-S.T.s.-S.T.pol.",
    "STsbr": "S.T.s.br.",
    "STs": "S.T.s.",
    "ScCal-SLi": "Sc.Cal.-S.Li.",
    "SsP-SPaint": "S.s.P.-S.Pa.int.",
    "FIP-FIPPoCinf": "F.I.P.-F.I.P.Po.C.inf.",
    "SCall-SsP-SintraCing": "S.Call.-S.s.P.-S.intraCing.",
    "SCall" : "S.Call.",
    "SOr" : "S.Or."
}

# %%
res
# Out:
#                           region     p   side
# 0    FCLp-subsc-FCLa-INSULA_left  19.0   left
# 1   FCLp-subsc-FCLa-INSULA_right  11.0  right
# 2               FCMpost-SpC_left   4.0   left
# 3              FCMpost-SpC_right   5.0  right
# 4                 FColl-SRh_left  13.0   left
# 5                FColl-SRh_right  17.0  right
# 6             FIP-FIPPoCinf_left  12.0   left
# 7            FIP-FIPPoCinf_right   6.0  right
# 8             FPO-SCu-ScCal_left   6.0   left
# 9            FPO-SCu-ScCal_right   5.0  right
# 10      Lobule_parietal_sup_left   9.0   left
# 11     Lobule_parietal_sup_right   6.0  right
# 12                OCCIPITAL_left   5.0   left
# 13               OCCIPITAL_right   3.0  right
# 14                  SC-SPeC_left   7.0   left
# 15                 SC-SPeC_right   7.0  right
# 16                  SC-SPoC_left  12.0   left
# 17                 SC-SPoC_right   6.0  right
# 18                  SC-sylv_left   6.0   left
# 19                 SC-sylv_right   4.0  right
# 20     SCall-SsP-SintraCing_left   5.0   left
# 21    SCall-SsP-SintraCing_right   3.0  right
# 22                    SCall_left   3.0   left
# 23                   SCall_right   1.0  right
# 24      SFinf-BROCA-SPeCinf_left  10.0   left
# 25     SFinf-BROCA-SPeCinf_right   8.0  right
# 26             SFint-FCMant_left   6.0   left
# 27            SFint-FCMant_right   5.0  right
# 28                 SFint-SR_left   8.0   left
# 29                SFint-SR_right   4.0  right
# 30            SFinter-SFsup_left   7.0   left
# 31           SFinter-SFsup_right  10.0  right
# 32      SFmarginal-SFinfant_left   3.0   left
# 33     SFmarginal-SFinfant_right   1.0  right
# 34   SFmedian-SFpoltr-SFsup_left   6.0   left
# 35  SFmedian-SFpoltr-SFsup_right  11.0  right
# 36                 SOr-SOlf_left   1.0   left
# 37                SOr-SOlf_right   3.0  right
# 38                      SOr_left   1.0   left
# 39                     SOr_right   3.0  right
# 40                     SPeC_left   4.0   left
# 41                    SPeC_right   5.0  right
# 42                     SPoC_left   9.0   left
# 43                    SPoC_right   4.0  right
# 44               STi-SOTlat_left  20.0   left
# 45              STi-SOTlat_right  12.0  right
# 46            STi-STs-STpol_left  29.0   left
# 47           STi-STs-STpol_right  15.0  right
# 48                      STs_left  22.0   left
# 49                     STs_right  11.0  right
# 50                    STsbr_left  16.0   left
# 51                   STsbr_right   7.0  right
# 52                ScCal-SLi_left   5.0   left
# 53               ScCal-SLi_right   3.0  right
# 54               SsP-SPaint_left   4.0   left
# 55              SsP-SPaint_right   4.0  right

# %%
import re

# %%
for key in dic.keys():
    res["region"] = res["region"].str.replace(key, dic[key])
res
# Out:
#                                     region     p   side
# 0    F.C.L.p.-subsc.-F.C.L.a.-INSULA._left  19.0   left
# 1   F.C.L.p.-subsc.-F.C.L.a.-INSULA._right  11.0  right
# 2                  F.C.M.post.-S.p.C._left   4.0   left
# 3                 F.C.M.post.-S.p.C._right   5.0  right
# 4                       F.Coll.-S.Rh._left  13.0   left
# 5                      F.Coll.-S.Rh._right  17.0  right
# 6                 F.I.P.-F.I.P.PoCinf_left  12.0   left
# 7                F.I.P.-F.I.P.PoCinf_right   6.0  right
# 8                F.P.O.-S.Cu.-Sc.Cal._left   6.0   left
# 9               F.P.O.-S.Cu.-Sc.Cal._right   5.0  right
# 10               Lobule_parietal_sup._left   9.0   left
# 11              Lobule_parietal_sup._right   6.0  right
# 12                          OCCIPITAL_left   5.0   left
# 13                         OCCIPITAL_right   3.0  right
# 14                       S.C.-S.Pe.C._left   7.0   left
# 15                      S.C.-S.Pe.C._right   7.0  right
# 16                       S.C.-S.Po.C._left  12.0   left
# 17                      S.C.-S.Po.C._right   6.0  right
# 18                         S.C.-sylv._left   6.0   left
# 19                        S.C.-sylv._right   4.0  right
# 20        S.Call.-S.s.P.-S.intraCing._left   5.0   left
# 21       S.Call.-S.s.P.-S.intraCing._right   3.0  right
# 22                            S.Call._left   3.0   left
# 23                           S.Call._right   1.0  right
# 24         S.F.inf.-BROCA-S.Pe.C.inf._left  10.0   left
# 25        S.F.inf.-BROCA-S.Pe.C.inf._right   8.0  right
# 26                S.F.int.-F.C.M.ant._left   6.0   left
# 27               S.F.int.-F.C.M.ant._right   5.0  right
# 28                      S.F.int.-S.R._left   8.0   left
# 29                     S.F.int.-S.R._right   4.0  right
# 30                S.F.inter.-S.F.sup._left   7.0   left
# 31               S.F.inter.-S.F.sup._right  10.0  right
# 32          S.F.marginal-S.F.inf.ant._left   3.0   left
# 33         S.F.marginal-S.F.inf.ant._right   1.0  right
# 34    S.F.median-S.F.pol.tr.-S.F.sup._left   6.0   left
# 35   S.F.median-S.F.pol.tr.-S.F.sup._right  11.0  right
# 36                       S.Or.-S.Olf._left   1.0   left
# 37                      S.Or.-S.Olf._right   3.0  right
# 38                              S.Or._left   1.0   left
# 39                             S.Or._right   3.0  right
# 40                            S.Pe.C._left   4.0   left
# 41                           S.Pe.C._right   5.0  right
# 42                            S.Po.C._left   9.0   left
# 43                           S.Po.C._right   4.0  right
# 44                  S.T.i.-S.O.T.lat._left  20.0   left
# 45                 S.T.i.-S.O.T.lat._right  12.0  right
# 46             S.T.i.-S.T.s.-S.T.pol._left  29.0   left
# 47            S.T.i.-S.T.s.-S.T.pol._right  15.0  right
# 48                             S.T.s._left  22.0   left
# 49                            S.T.s._right  11.0  right
# 50                          S.T.s.br._left  16.0   left
# 51                         S.T.s.br._right   7.0  right
# 52                      Sc.Cal.-S.Li._left   5.0   left
# 53                     Sc.Cal.-S.Li._right   3.0  right
# 54                   S.s.P.-S.Pa.int._left   4.0   left
# 55                  S.s.P.-S.Pa.int._right   4.0  right

# %%
res.loc[6, "region"] = "F.I.P.-F.I.P.Po.C.inf._left"
res.loc[7, "region"] = "F.I.P.-F.I.P.Po.C.inf._right"
res
# Out:
#                                     region     p   side
# 0    F.C.L.p.-subsc.-F.C.L.a.-INSULA._left  19.0   left
# 1   F.C.L.p.-subsc.-F.C.L.a.-INSULA._right  11.0  right
# 2                  F.C.M.post.-S.p.C._left   4.0   left
# 3                 F.C.M.post.-S.p.C._right   5.0  right
# 4                       F.Coll.-S.Rh._left  13.0   left
# 5                      F.Coll.-S.Rh._right  17.0  right
# 6              F.I.P.-F.I.P.Po.C.inf._left  12.0   left
# 7             F.I.P.-F.I.P.Po.C.inf._right   6.0  right
# 8                F.P.O.-S.Cu.-Sc.Cal._left   6.0   left
# 9               F.P.O.-S.Cu.-Sc.Cal._right   5.0  right
# 10               Lobule_parietal_sup._left   9.0   left
# 11              Lobule_parietal_sup._right   6.0  right
# 12                          OCCIPITAL_left   5.0   left
# 13                         OCCIPITAL_right   3.0  right
# 14                       S.C.-S.Pe.C._left   7.0   left
# 15                      S.C.-S.Pe.C._right   7.0  right
# 16                       S.C.-S.Po.C._left  12.0   left
# 17                      S.C.-S.Po.C._right   6.0  right
# 18                         S.C.-sylv._left   6.0   left
# 19                        S.C.-sylv._right   4.0  right
# 20        S.Call.-S.s.P.-S.intraCing._left   5.0   left
# 21       S.Call.-S.s.P.-S.intraCing._right   3.0  right
# 22                            S.Call._left   3.0   left
# 23                           S.Call._right   1.0  right
# 24         S.F.inf.-BROCA-S.Pe.C.inf._left  10.0   left
# 25        S.F.inf.-BROCA-S.Pe.C.inf._right   8.0  right
# 26                S.F.int.-F.C.M.ant._left   6.0   left
# 27               S.F.int.-F.C.M.ant._right   5.0  right
# 28                      S.F.int.-S.R._left   8.0   left
# 29                     S.F.int.-S.R._right   4.0  right
# 30                S.F.inter.-S.F.sup._left   7.0   left
# 31               S.F.inter.-S.F.sup._right  10.0  right
# 32          S.F.marginal-S.F.inf.ant._left   3.0   left
# 33         S.F.marginal-S.F.inf.ant._right   1.0  right
# 34    S.F.median-S.F.pol.tr.-S.F.sup._left   6.0   left
# 35   S.F.median-S.F.pol.tr.-S.F.sup._right  11.0  right
# 36                       S.Or.-S.Olf._left   1.0   left
# 37                      S.Or.-S.Olf._right   3.0  right
# 38                              S.Or._left   1.0   left
# 39                             S.Or._right   3.0  right
# 40                            S.Pe.C._left   4.0   left
# 41                           S.Pe.C._right   5.0  right
# 42                            S.Po.C._left   9.0   left
# 43                           S.Po.C._right   4.0  right
# 44                  S.T.i.-S.O.T.lat._left  20.0   left
# 45                 S.T.i.-S.O.T.lat._right  12.0  right
# 46             S.T.i.-S.T.s.-S.T.pol._left  29.0   left
# 47            S.T.i.-S.T.s.-S.T.pol._right  15.0  right
# 48                             S.T.s._left  22.0   left
# 49                            S.T.s._right  11.0  right
# 50                          S.T.s.br._left  16.0   left
# 51                         S.T.s.br._right   7.0  right
# 52                      Sc.Cal.-S.Li._left   5.0   left
# 53                     Sc.Cal.-S.Li._right   3.0  right
# 54                   S.s.P.-S.Pa.int._left   4.0   left
# 55                  S.s.P.-S.Pa.int._right   4.0  right

# %%
res['sulcus'] = res.apply(lambda x: get_sulci(x.region), axis=1)
res.head()
# Out:
#                                    region     p   side  \
# 0   F.C.L.p.-subsc.-F.C.L.a.-INSULA._left  19.0   left
# 1  F.C.L.p.-subsc.-F.C.L.a.-INSULA._right  11.0  right
# 2                 F.C.M.post.-S.p.C._left   4.0   left
# 3                F.C.M.post.-S.p.C._right   5.0  right
# 4                      F.Coll.-S.Rh._left  13.0   left
#
#                                               sulcus
# 0  [F.C.L.p._left, F.C.L.r.sc.ant._left, F.C.L.r....
# 1  [F.C.L.p._right, F.C.L.r.sc.ant._right, F.C.L....
# 2     [F.C.M.post._left, S.C.LPC._left, S.p.C._left]
# 3  [F.C.M.post._right, S.C.LPC._right, S.p.C._right]
# 4                         [F.Coll._left, S.Rh._left]

# %%
res = res.sort_values(by="p", ascending=False)
res = res.explode("sulcus")
res[res.region.str.contains("S.T.s.")]
# Out:
#                           region     p   side                     sulcus
# 46   S.T.i.-S.T.s.-S.T.pol._left  29.0   left            S.T.i.ant._left
# 46   S.T.i.-S.T.s.-S.T.pol._left  29.0   left           S.T.i.post._left
# 46   S.T.i.-S.T.s.-S.T.pol._left  29.0   left                S.T.s._left
# 46   S.T.i.-S.T.s.-S.T.pol._left  29.0   left              S.T.pol._left
# 48                   S.T.s._left  22.0   left                S.T.s._left
# 50                S.T.s.br._left  16.0   left         F.I.P.r.int.1_left
# 50                S.T.s.br._left  16.0   left         F.I.P.r.int.2_left
# 50                S.T.s.br._left  16.0   left    S.T.s.ter.asc.ant._left
# 50                S.T.s.br._left  16.0   left   S.T.s.ter.asc.post._left
# 50                S.T.s.br._left  16.0   left                S.GSM._left
# 47  S.T.i.-S.T.s.-S.T.pol._right  15.0  right           S.T.i.ant._right
# 47  S.T.i.-S.T.s.-S.T.pol._right  15.0  right          S.T.i.post._right
# 47  S.T.i.-S.T.s.-S.T.pol._right  15.0  right               S.T.s._right
# 47  S.T.i.-S.T.s.-S.T.pol._right  15.0  right             S.T.pol._right
# 49                  S.T.s._right  11.0  right               S.T.s._right
# 51               S.T.s.br._right   7.0  right        F.I.P.r.int.1_right
# 51               S.T.s.br._right   7.0  right        F.I.P.r.int.2_right
# 51               S.T.s.br._right   7.0  right   S.T.s.ter.asc.ant._right
# 51               S.T.s.br._right   7.0  right  S.T.s.ter.asc.post._right
# 51               S.T.s.br._right   7.0  right               S.GSM._right

# %%
for _, row in res.iterrows():
    print(row.sulcus)
# Out:
# S.T.i.ant._left
# S.T.i.post._left
# S.T.s._left
# S.T.pol._left
# S.T.s._left
# S.T.i.ant._left
# S.T.i.post._left
# S.O.T.lat.ant._left
# S.O.T.lat.int._left
# S.O.T.lat.med._left
# S.O.T.lat.post._left
# F.C.L.p._left
# F.C.L.r.sc.ant._left
# F.C.L.r.sc.post._left
# INSULA_left
# F.C.L.a._left
# F.Coll._right
# S.Rh._right
# F.I.P.r.int.1_left
# F.I.P.r.int.2_left
# S.T.s.ter.asc.ant._left
# S.T.s.ter.asc.post._left
# S.GSM._left
# S.T.i.ant._right
# S.T.i.post._right
# S.T.s._right
# S.T.pol._right
# F.Coll._left
# S.Rh._left
# F.I.P._left
# F.I.P.Po.C.inf._left
# S.T.i.ant._right
# S.T.i.post._right
# S.O.T.lat.ant._right
# S.O.T.lat.int._right
# S.O.T.lat.med._right
# S.O.T.lat.post._right
# S.C._left
# S.C.sylvian._left
# S.Po.C.sup._left
# F.I.P.Po.C.inf._left
# F.C.L.r.retroC.tr._left
# S.T.s._right
# S.F.median._right
# S.F.polaire.tr._right
# S.F.sup._right
# F.C.L.p._right
# F.C.L.r.sc.ant._right
# F.C.L.r.sc.post._right
# INSULA_right
# F.C.L.a._right
# S.F.inf._left
# S.F.inf.ant._left
# F.C.L.r.ant._left
# F.C.L.r.asc._left
# F.C.L.r.diag._left
# S.Pe.C.inf._left
# S.F.inter._right
# S.F.sup._right
# F.I.P._left
# S.Po.C.sup._left
# S.Pa.sup._left
# S.Po.C.sup._left
# F.I.P.Po.C.inf._left
# F.C.L.r.retroC.tr._left
# S.F.inf._right
# S.F.inf.ant._right
# F.C.L.r.ant._right
# F.C.L.r.asc._right
# F.C.L.r.diag._right
# S.Pe.C.inf._right
# S.F.int._left
# S.R.inf._left
# S.R.sup._left
# S.F.inter._left
# S.F.sup._left
# F.I.P.r.int.1_right
# F.I.P.r.int.2_right
# S.T.s.ter.asc.ant._right
# S.T.s.ter.asc.post._right
# S.GSM._right
# S.C._left
# S.C.sylvian._left
# S.Pe.C.inf._left
# S.Pe.C.inter._left
# S.Pe.C.marginal._left
# S.Pe.C.sup._left
# S.Pe.C.median._left
# S.C._right
# S.C.sylvian._right
# S.Pe.C.inf._right
# S.Pe.C.inter._right
# S.Pe.C.marginal._right
# S.Pe.C.sup._right
# S.Pe.C.median._right
# F.I.P._right
# F.I.P.Po.C.inf._right
# F.I.P._right
# S.Po.C.sup._right
# S.Pa.sup._right
# S.C._left
# S.C.sylvian._left
# F.C.M.ant._left
# S.F.int._left
# S.C._right
# S.C.sylvian._right
# S.Po.C.sup._right
# F.I.P.Po.C.inf._right
# F.C.L.r.retroC.tr._right
# F.P.O._left
# S.Pa.t._left
# S.Cu._left
# F.Cal.ant.-Sc.Cal._left
# S.O.p._left
# S.F.median._left
# S.F.polaire.tr._left
# S.F.sup._left
# OCCIPITAL_left
# F.P.O._right
# S.Pa.t._right
# S.Cu._right
# F.Cal.ant.-Sc.Cal._right
# S.O.p._right
# S.Call._left
# S.s.P._left
# S.intraCing._left
# F.C.M.post._right
# S.C.LPC._right
# S.p.C._right
# S.Pe.C.inf._right
# S.Pe.C.inter._right
# S.Pe.C.marginal._right
# S.Pe.C.sup._right
# S.Pe.C.median._right
# F.C.M.ant._right
# S.F.int._right
# F.Cal.ant.-Sc.Cal._left
# S.O.p._left
# S.Li.ant._left
# S.Li.post._left
# F.C.M.post._left
# S.C.LPC._left
# S.p.C._left
# S.s.P._left
# S.Pa.int._left
# S.Po.C.sup._right
# F.I.P.Po.C.inf._right
# F.C.L.r.retroC.tr._right
# S.s.P._right
# S.Pa.int._right
# S.Pe.C.inf._left
# S.Pe.C.inter._left
# S.Pe.C.marginal._left
# S.Pe.C.sup._left
# S.Pe.C.median._left
# S.F.int._right
# S.R.inf._right
# S.R.sup._right
# S.C._right
# S.C.sylvian._right
# OCCIPITAL_right
# S.Or._right
# S.Call._right
# S.s.P._right
# S.intraCing._right
# S.Or._right
# S.Olf._right
# S.F.marginal._left
# S.F.orbitaire._left
# S.F.inf.ant._left
# F.Cal.ant.-Sc.Cal._right
# S.O.p._right
# S.Li.ant._right
# S.Li.post._right
# S.Call._left
# S.Or._left
# S.Olf._left
# S.F.marginal._right
# S.F.orbitaire._right
# S.F.inf.ant._right
# S.Call._right
# S.Or._left

# %%
res[res.sulcus=="S.F.orbitaire._right"]
# Out:
#                              region    p   side                sulcus
# 33  S.F.marginal-S.F.inf.ant._right  1.0  right  S.F.orbitaire._right

# %%
res
# Out:
#                              region     p   side                sulcus
# 46      S.T.i.-S.T.s.-S.T.pol._left  29.0   left       S.T.i.ant._left
# 46      S.T.i.-S.T.s.-S.T.pol._left  29.0   left      S.T.i.post._left
# 46      S.T.i.-S.T.s.-S.T.pol._left  29.0   left           S.T.s._left
# 46      S.T.i.-S.T.s.-S.T.pol._left  29.0   left         S.T.pol._left
# 48                      S.T.s._left  22.0   left           S.T.s._left
# ..                              ...   ...    ...                   ...
# 33  S.F.marginal-S.F.inf.ant._right   1.0  right   S.F.marginal._right
# 33  S.F.marginal-S.F.inf.ant._right   1.0  right  S.F.orbitaire._right
# 33  S.F.marginal-S.F.inf.ant._right   1.0  right    S.F.inf.ant._right
# 23                    S.Call._right   1.0  right         S.Call._right
# 38                       S.Or._left   1.0   left            S.Or._left
#
# [182 rows x 4 columns]

# %%
def set_color_property(res, side):
    global dic

    if side == "L":
        spam_model_file = Lspam_model
    else:
        spam_model_file = Rspam_model
        
    dic[f"aims{side}"] = aims.read(spam_model_file)

    for vertex in dic[f"aims{side}"].vertices():
        vertex['p_value'] = 0.

    for _, row in res.iterrows():
        for vertex in dic[f"aims{side}"].vertices():
            vname = vertex.get('name')
            if vname == row.sulcus:
                    vertex['p_value'] = max(vertex['p_value'],
                                                row.p)
                    # if row.p < -np.log10(0.05/56):
                    #     vertex['p_value'] = 0.
                    # elif vertex['p_value'] != 0.: 
                    #     vertex['p_value'] = min(vertex['p_value'],
                    #                             row.p)
                    # else:
                    #     vertex['p_value'] = row.p
    
    dic[f"ana{side}"] = a.toAObject(dic[f"aims{side}"])

    dic[f"ana{side}"].setColorMode(dic[f"ana{side}"].PropertyMap)
    dic[f"ana{side}"].setColorProperty('p_value')
    dic[f"ana{side}"].notifyObservers()
    
                
def visualize_whole_hemisphere(view_quaternion, side, i):
    global block
    global dic
    try:
        block
    except NameError:
        block = a.createWindowsBlock(4)

    dic[f"win{i}"] = a.createWindow('3D',
                                    block=block,
                                    no_decoration=True,
                                    options={'hidden': 1})
    dic[f"win{i}"].addObjects(dic[f"ana{side}"])
    dic[f"ana{side}"].setPalette("green_yellow_red",
                              minVal=min(res["p"]), maxVal=max(res["p"]),
                              absoluteMode=True)
    
    dic[f"win{i}"].camera(view_quaternion=view_quaternion)

middle_view = [0.5, -0.5, -0.5, 0.5]
side_view = [0.5, 0.5, 0.5, 0.5]
bottom_view = [0, -1, 0, 0]
top_view = [0, 0, 0, -1]
 
def visualize_whole(res, side, start):
    set_color_property(res, side)
    visualize_whole_hemisphere(middle_view if side == "L" else side_view, side, start+0)
    visualize_whole_hemisphere(top_view, side, start+1)
    visualize_whole_hemisphere(bottom_view, side, start+2)
    visualize_whole_hemisphere(side_view if side == "L" else middle_view, side, start+3)

# %%
max(res["p"])
# Out:
# 29.0

# %%
min(res["p"])
# Out:
# 1.0

# %%
dic = {}

visualize_whole(res, "L", 0)
visualize_whole(res, "R", 4)
